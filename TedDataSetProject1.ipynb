# %% [markdown]
# <a href="https://colab.research.google.com/github/mertyuksel-tr/Binary-Search-Tree-Projesi/blob/main/TedDataSetProject1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 

import pandas as pd

# %%
df = pd.read_csv("/content/data.csv")

df.head()
# Out:
#                                                title                author  \
# 0      Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1        The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2     How play can spark new ideas for your business         Martin Reeves
# 3  Why is China appointing judges to combat clima...     James K. Thornton
# 4     Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
#
#              date   views  likes  \
# 0   December 2021  404000  12000
# 1   February 2022  214000   6400
# 2  September 2021  412000  12000
# 3    October 2021  427000  12000
# 4    October 2021    2400     72
#
#                                                 link
# 0  https://ted.com/talks/ozawa_bineshi_albert_cli...
# 1  https://ted.com/talks/sydney_iaukea_the_dark_h...
# 2  https://ted.com/talks/martin_reeves_how_play_c...
# 3  https://ted.com/talks/james_k_thornton_why_is_...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5440 entries, 0 to 5439
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   5440 non-null   object
#  1   author  5439 non-null   object
#  2   date    5440 non-null   object
#  3   views   5440 non-null   int64
#  4   likes   5440 non-null   int64
#  5   link    5440 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 255.1+ KB

# %%
df.dtypes
# Out:
# title     object
# author    object
# date      object
# views      int64
# likes      int64
# link      object
# dtype: object

# %%
df.size
# Out:
# 32640

# %%
df.describe().T
# Out:
#         count          mean           std    min       25%        50%  \
# views  5440.0  2.061576e+06  3.567098e+06  532.0  670750.0  1300000.0
# likes  5440.0  6.260762e+04  1.076468e+05   15.0   20000.0    40500.0
#
#              75%         max
# views  2100000.0  72000000.0
# likes    65000.0   2100000.0

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.isnull().sum()
# Out:
# title     0
# author    1
# date      0
# views     0
# likes     0
# link      0
# dtype: int64

# %%
df.sort_values(by ='views', ascending = False)
# Out:
#                                                   title  \
# 5436                        Do schools kill creativity?
# 4084           Your body language may shape who you are
# 2958         Inside the mind of a master procrastinator
# 4765                   How great leaders inspire action
# 4605                         The power of vulnerability
# ...                                                 ...
# 552                                      Virtual Worlds
# 1064  "Jamie Raeburn" / "Baloo Baleerie" / "Twa recr...
# 1692  "Part II. The Journey Through Time" / "Ruslan ...
# 613                  Post-Pandemic Paradise in Rapa Nui
# 3039                                 Year In Ideas 2015
#
#                                 author            date     views    likes  \
# 5436                  Sir Ken Robinson   February 2006  72000000  2100000
# 4084                         Amy Cuddy       June 2012  64000000  1900000
# ...

# %%
df.sort_values(by ='likes', ascending = False)
# Out:
#                                                   title  \
# 5436                        Do schools kill creativity?
# 4084           Your body language may shape who you are
# 2958         Inside the mind of a master procrastinator
# 4605                         The power of vulnerability
# 4765                   How great leaders inspire action
# ...                                                 ...
# 1692  "Part II. The Journey Through Time" / "Ruslan ...
# 1064  "Jamie Raeburn" / "Baloo Baleerie" / "Twa recr...
# 552                                      Virtual Worlds
# 613                  Post-Pandemic Paradise in Rapa Nui
# 3039                                 Year In Ideas 2015
#
#                                 author            date     views    likes  \
# 5436                  Sir Ken Robinson   February 2006  72000000  2100000
# 4084                         Amy Cuddy       June 2012  64000000  1900000
# ...

# %%
df.sort_values(by ='date', ascending = False)
# Out:
#                                                   title  \
# 124                                   "Back on My Feet"
# 213     The secrets of the world's most famous symphony
# 75             Siri, Alexa, Google ... what comes next?
# 59    What makes a job "good" — and the case for inv...
# 55    How biochar removes CO2 from the air — and hel...
# ...                                                 ...
# 4628                     What a bike ride can teach you
# 4626                        Making law on the high seas
# 4311                               Hooked by an octopus
# 4690                    Learning from Sherman the shark
# 4986          A passionate, personal case for education
#
#                         author            date    views  likes  \
# 124                  Kimberose  September 2021     3000     91
# 213              Hanako Sawada  September 2021  1100000  34000
# 75    Karen Lellouche Tordjman  September 2021  1000000  32000
# ...

# %%
df.groupby('author').size().sort_values(ascending = False).head()
# Out:
# author
# Alex Gendler        45
# Iseult Gillespie    33
# Matt Walker         18
# Alex Rosenthal      15
# Elizabeth Cox       13
# dtype: int64

# %%
month = []
year = []

for date in df['date']:
    month.append(date.split(' ')[0])
    year.append(date.split(' ')[1]) 
    
df['month'] = month 
df['year'] = year

df.head()
# Out:
#                                                title                author  \
# 0      Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1        The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2     How play can spark new ideas for your business         Martin Reeves
# 3  Why is China appointing judges to combat clima...     James K. Thornton
# 4     Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
#
#              date   views  likes  \
# 0   December 2021  404000  12000
# 1   February 2022  214000   6400
# 2  September 2021  412000  12000
# 3    October 2021  427000  12000
# 4    October 2021    2400     72
#
#                                                 link      month  year
# 0  https://ted.com/talks/ozawa_bineshi_albert_cli...   December  2021
# 1  https://ted.com/talks/sydney_iaukea_the_dark_h...   February  2022
# 2  https://ted.com/talks/martin_reeves_how_play_c...  September  2021
# ...

# %%
df.groupby('month').size().sort_values(ascending = False).plot(kind = 'bar')

# %%
df.groupby('year').size().plot(kind = 'bar')

# %%
plt.figure(figsize=(10,6))
thisPlot = sns.catplot(data=df,x='month', col='year',  kind="count", col_wrap=6, height=4, aspect=.7)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
plt.figure(figsize=(14,6))
sns.countplot(df['year'], data = df)
plt.xticks()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df.groupby(df['year']).sum()
# Out:
#            views     likes
# year
# 1970      252000      7500
# 1972     1300000     41000
# 1983      690000     20000
# 1984     1100000     33000
# 1990      723000     21000
# 1991      327000      9800
# 1994      699000     20000
# 1998     7410000    226100
# 2001    10530000    315100
# 2002    30442000    915700
# 2003    54394000   1640400
# 2004   112378000   3436400
# 2005   157477999   4805000
# 2006   181109999   5401400
# 2007   176651000   5332100
# 2008   208007999   6312400
# 2009   557635000  16841500
# 2010   528145999  15962900
# 2011   575677999  17478900
# 2012   803186000  24331209
# 2013  1062537497  32249916
# 2014   824652297  25076665
# 2015  1154740130  35151761
# 2016   928894896  28306782
# 2017   998891600  30516328
# 2018   811857597  24671493
# 2019   948119299  28764575
# 2020   635944200  19297014
# 2021   429728700  13058238
# 2022    11470000    341254

# %%
plt.figure(figsize=(14,6))
sns.countplot(df['month'], data = df)
plt.xticks()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
a = df.groupby(df['year'])['likes'].mean()

# %%
plt.plot(a)

# %%
authorsGroup = df.groupby('author')

# %%
mostViewedAuthors = authorsGroup['views'].sum().sort_values(ascending=False)
mostViewedAuthors[:15]
# Out:
# author
# Alex Gendler        187196000
# Sir Ken Robinson     95654000
# Bill Gates           77800000
# Simon Sinek          74800000
# Brené Brown          72000000
# Julian Treasure      64300000
# Amy Cuddy            64000000
# Tim Urban            60000000
# Iseult Gillespie     54998000
# Mia Nacamulli        44174000
# Sam Berns            43000000
# Robert Waldinger     41000000
# Esther Perel         39400000
# Cameron Russell      38000000
# Mary Roach           37000000
# Name: views, dtype: int64

# %%
plt.figure(figsize=(10,6))
mostViewedAuthors[:15].plot(kind='bar')
plt.ylabel('Sayı Görüntüleme (yüz milyon)')
plt.title("En Çok İzlenen 15 TED Konuşmacısı")
# Out:
# Text(0.5, 1.0, 'En Çok İzlenen 15 TED Konuşmacısı')
